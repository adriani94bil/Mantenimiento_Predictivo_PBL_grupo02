# %% [markdown]
# # EDA IMAGENES

# %%
import numpy as np
import pandas as pd
import os
from PIL import Image
import shutil

# %%
def get_jpg_paths(directory):
    """
    Recorre una carpeta y sus subcarpetas para encontrar archivos con extensión .jpeg.
    Retorna un DataFrame con una columna 'relative_path' que contiene los caminos relativos de las imágenes.
    
    Parameters:
        directory (str): El path a la carpeta raíz que contiene las subcarpetas.
    
    Returns:
        pd.DataFrame: Un DataFrame con los caminos relativos de las imágenes .jpeg.
    """
    jpg_paths = []
    
    # Recorre todas las carpetas y archivos dentro del directorio
    for root, _, files in os.walk(directory):
        for file in files:
            if file.lower().endswith('.jpg'):  # Aseguramos que la extensión sea .jpeg
                # Calculamos el camino relativo
                relative_path = os.path.relpath(os.path.join(root, file), start=directory)
                jpg_paths.append(relative_path)
    
    # Creamos un DataFrame con los resultados
    df = pd.DataFrame(jpg_paths, columns=['relative_path'])
    return df

# %%
directory = r"C:\Users\Adrian\Documents\MONDRAGON\PBL2 Grupo 02\Mantenimiento_Predictivo_PBL_grupo02\product_fault"  # Ruta de la carpeta raíz
df = get_jpg_paths(directory)

# %%
df
# Out:
#        relative_path
# 0    kos01\Part0.jpg
# 1    kos01\Part1.jpg
# 2    kos01\Part2.jpg
# 3    kos01\Part3.jpg
# 4    kos01\Part4.jpg
# ..               ...
# 394  kos50\Part3.jpg
# 395  kos50\Part4.jpg
# 396  kos50\Part5.jpg
# 397  kos50\Part6.jpg
# 398  kos50\Part7.jpg
#
# [399 rows x 1 columns]

# %% [markdown]
# Tenemos 399 productos a los que se les ha puesto una máscara para saber si tienen defecto o no vamos a generar un dataframe con

# %%
import os

import pandas as pd

def get_jpg_paths_with_defects(directory):
    """
    Busca archivos .jpeg en una carpeta y sus subcarpetas, verifica si su archivo .bmp correspondiente tiene píxeles blancos.
    El archivo .bmp correspondiente tiene el mismo nombre que el .jpeg pero con el sufijo '_label'.
    Devuelve un DataFrame con las columnas 'relative_path' y 'defecto'.
    
    Parameters:
        directory (str): El path a la carpeta raíz que contiene las subcarpetas.
    
    Returns:
        pd.DataFrame: Un DataFrame con los caminos relativos de las imágenes .jpeg y la columna 'defecto'.
    """
    jpg_paths = []
    defects = []

    # Recorre todas las carpetas y archivos dentro del directorio
    for root, _, files in os.walk(directory):
        for file in files:
            if file.lower().endswith('.jpg'):  # Aseguramos que la extensión sea .jpeg
                # Calculamos el camino relativo del archivo .jpeg
                relative_path_jpg = os.path.relpath(os.path.join(root, file), start=directory)
                jpg_paths.append(relative_path_jpg)

                # Verificamos si el archivo .bmp correspondiente existe
                bmp_filename = os.path.splitext(file)[0] + "_label.bmp"  # Añadimos '_label' al nombre base
                bmp_filepath = os.path.join(root, bmp_filename)
                
                if os.path.exists(bmp_filepath):
                    # Abrimos la imagen .bmp y verificamos si contiene píxeles blancos
                    try:
                        with Image.open(bmp_filepath) as bmp_image:
                            # Convertimos la imagen a modo 'RGB' si no lo está
                            if bmp_image.mode != 'RGB':
                                bmp_image = bmp_image.convert('RGB')
                            # Extraemos los datos de los píxeles
                            pixels = list(bmp_image.getdata())
                            # Buscamos un píxel blanco (255, 255, 255)
                            has_white_pixel = any(pixel == (255, 255, 255) for pixel in pixels)
                            defects.append(1 if has_white_pixel else 0)
                    except Exception as e:
                        print(f"Error procesando el archivo {bmp_filepath}: {e}")
                        defects.append(1)  # Consideramos que no tiene defecto en caso de error
                else:
                    defects.append(1)  # Si no existe el archivo .bmp, asumimos sin defecto

    # Creamos un DataFrame con los resultados
    df = pd.DataFrame({
        'relative_path': jpg_paths,
        'defecto': defects
    })
    return df

# %%
directory = r"C:\Users\Adrian\Documents\MONDRAGON\PBL2 Grupo 02\Mantenimiento_Predictivo_PBL_grupo02\product_fault"  # Ruta de la carpeta raíz
df = get_jpg_paths_with_defects(directory)
print(df)
# Out:
#        relative_path  defecto
# 0    kos01\Part0.jpg        0
# 1    kos01\Part1.jpg        0
# 2    kos01\Part2.jpg        0
# 3    kos01\Part3.jpg        0
# 4    kos01\Part4.jpg        0
# ..               ...      ...
# 394  kos50\Part3.jpg        0
# 395  kos50\Part4.jpg        1
# 396  kos50\Part5.jpg        0
# 397  kos50\Part6.jpg        0
# 398  kos50\Part7.jpg        0
#
# [399 rows x 2 columns]

# %%
df['defecto'].value_counts()
# Out:
# defecto
# 0    347
# 1     52
# Name: count, dtype: int64

# %% [markdown]
# Como vemos, el dataset esta muy desbalanceado ya que tenemos 52 piezas con defecto y 347 sin defecto. Posteriormente se valorará si hacer oversampling de las piezas con defecto.

# %%
# Guardamos el DataFrame en un archivo CSV
df.to_csv("defectos_info.csv", index=False)

# %%
def augment_defective_images(df, source_dir, target_dir="data_augmentation"):
    """
    Copia todas las imágenes .jpg a 'data_augmentation'.
    - Si defecto == 1, genera:
      - Imagen rotada 180° (*_rot.jpg)
      - Imagen espejo horizontal (*_res.jpeg)
    - Si defecto == 0, copia el archivo *_label.bmp si existe.

    Parameters:
        df (pd.DataFrame): DataFrame con las columnas 'relative_path' y 'defecto'.
        source_dir (str): Directorio raíz donde están las imágenes originales.
        target_dir (str): Directorio donde se guardarán las imágenes aumentadas.
    """
    for index, row in df.iterrows():
        source_path = os.path.join(source_dir, row['relative_path'])
        
        # Obtener la ruta relativa y el nombre del archivo sin extensión
        relative_dir = os.path.dirname(row['relative_path'])
        filename_wo_ext = os.path.splitext(os.path.basename(row['relative_path']))[0]
        
        # Ruta para copiar la imagen original en data_augmentation
        original_aug_path = os.path.join(target_dir, relative_dir, f"{filename_wo_ext}.jpg")
        
        # Crear la estructura de carpetas en data_augmentation
        os.makedirs(os.path.dirname(original_aug_path), exist_ok=True)
        
        try:
            with Image.open(source_path) as img:
                # Copiar la imagen original
                img.save(original_aug_path)
                print(f"Imagen original guardada en: {original_aug_path}")
                
                if row['defecto'] == 1:
                    # Si tiene defecto, generar y guardar imagen rotada 180°
                    rot_aug_path = os.path.join(target_dir, relative_dir, f"{filename_wo_ext}_rot.jpg")
                    rotated_img = img.rotate(180)
                    rotated_img.save(rot_aug_path)
                    print(f"Imagen rotada guardada en: {rot_aug_path}")
                    
                    # Generar y guardar imagen espejo horizontal
                    res_aug_path = os.path.join(target_dir, relative_dir, f"{filename_wo_ext}_res.jpg")
                    flipped_img = img.transpose(Image.FLIP_LEFT_RIGHT)
                    flipped_img.save(res_aug_path)
                    print(f"Imagen espejo guardada en: {res_aug_path}")
                
                elif row['defecto'] == 0:
                    # Si no tiene defecto, copiar el archivo *_label.bmp si existe
                    bmp_filename = f"{filename_wo_ext}_label.bmp"
                    bmp_source_path = os.path.join(source_dir, relative_dir, bmp_filename)
                    bmp_aug_path = os.path.join(target_dir, relative_dir, bmp_filename)
                    
                    if os.path.exists(bmp_source_path):
                        shutil.copy2(bmp_source_path, bmp_aug_path)
                        print(f"Archivo .bmp copiado en: {bmp_aug_path}")
                    else:
                        print(f"Archivo .bmp no encontrado para: {bmp_source_path}")
                    
        except Exception as e:
            print(f"Error al procesar {source_path}: {e}")

# %%
augment_defective_images(df, directory, target_dir="data_augmentation")
# Out:
# Imagen original guardada en: data_augmentation\kos01\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos01\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos01\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos01\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos01\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos01\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos01\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos01\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos01\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos01\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos01\Part5.jpg
# Imagen rotada guardada en: data_augmentation\kos01\Part5_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos01\Part5_res.jpg
# Imagen original guardada en: data_augmentation\kos01\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos01\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos01\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos01\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos02\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos02\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos02\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos02\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos02\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos02\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos02\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos02\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos02\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos02\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos02\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos02\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos02\Part6.jpg
# Imagen rotada guardada en: data_augmentation\kos02\Part6_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos02\Part6_res.jpg
# Imagen original guardada en: data_augmentation\kos02\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos02\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos03\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos03\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos03\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos03\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos03\Part2.jpg
# Imagen rotada guardada en: data_augmentation\kos03\Part2_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos03\Part2_res.jpg
# Imagen original guardada en: data_augmentation\kos03\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos03\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos03\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos03\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos03\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos03\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos03\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos03\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos03\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos03\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos04\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos04\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos04\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos04\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos04\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos04\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos04\Part3.jpg
# Imagen rotada guardada en: data_augmentation\kos04\Part3_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos04\Part3_res.jpg
# Imagen original guardada en: data_augmentation\kos04\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos04\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos04\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos04\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos04\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos04\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos04\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos04\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos05\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos05\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos05\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos05\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos05\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos05\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos05\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos05\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos05\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos05\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos05\Part5.jpg
# Imagen rotada guardada en: data_augmentation\kos05\Part5_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos05\Part5_res.jpg
# Imagen original guardada en: data_augmentation\kos05\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos05\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos05\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos05\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos06\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos06\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos06\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos06\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos06\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos06\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos06\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos06\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos06\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos06\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos06\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos06\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos06\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos06\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos06\Part7.jpg
# Imagen rotada guardada en: data_augmentation\kos06\Part7_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos06\Part7_res.jpg
# Imagen original guardada en: data_augmentation\kos07\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos07\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos07\Part1.jpg
# Imagen rotada guardada en: data_augmentation\kos07\Part1_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos07\Part1_res.jpg
# Imagen original guardada en: data_augmentation\kos07\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos07\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos07\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos07\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos07\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos07\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos07\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos07\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos07\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos07\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos07\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos07\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos08\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos08\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos08\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos08\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos08\Part2.jpg
# Imagen rotada guardada en: data_augmentation\kos08\Part2_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos08\Part2_res.jpg
# Imagen original guardada en: data_augmentation\kos08\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos08\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos08\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos08\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos08\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos08\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos08\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos08\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos08\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos08\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos09\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos09\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos09\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos09\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos09\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos09\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos09\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos09\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos09\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos09\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos09\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos09\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos09\Part6.jpg
# Imagen rotada guardada en: data_augmentation\kos09\Part6_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos09\Part6_res.jpg
# Imagen original guardada en: data_augmentation\kos09\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos09\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos10\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos10\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos10\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos10\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos10\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos10\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos10\Part3.jpg
# Imagen rotada guardada en: data_augmentation\kos10\Part3_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos10\Part3_res.jpg
# Imagen original guardada en: data_augmentation\kos10\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos10\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos10\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos10\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos10\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos10\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos10\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos10\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos11\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos11\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos11\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos11\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos11\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos11\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos11\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos11\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos11\Part4.jpg
# Imagen rotada guardada en: data_augmentation\kos11\Part4_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos11\Part4_res.jpg
# Imagen original guardada en: data_augmentation\kos11\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos11\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos11\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos11\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos11\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos11\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos12\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos12\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos12\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos12\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos12\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos12\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos12\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos12\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos12\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos12\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos12\Part5.jpg
# Imagen rotada guardada en: data_augmentation\kos12\Part5_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos12\Part5_res.jpg
# Imagen original guardada en: data_augmentation\kos12\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos12\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos12\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos12\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos13\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos13\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos13\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos13\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos13\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos13\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos13\Part3.jpg
# Imagen rotada guardada en: data_augmentation\kos13\Part3_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos13\Part3_res.jpg
# Imagen original guardada en: data_augmentation\kos13\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos13\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos13\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos13\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos13\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos13\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos13\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos13\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos14\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos14\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos14\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos14\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos14\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos14\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos14\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos14\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos14\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos14\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos14\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos14\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos14\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos14\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos14\Part7.jpg
# Imagen rotada guardada en: data_augmentation\kos14\Part7_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos14\Part7_res.jpg
# Imagen original guardada en: data_augmentation\kos15\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos15\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos15\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos15\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos15\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos15\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos15\Part3.jpg
# Imagen rotada guardada en: data_augmentation\kos15\Part3_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos15\Part3_res.jpg
# Imagen original guardada en: data_augmentation\kos15\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos15\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos15\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos15\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos15\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos15\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos15\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos15\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos16\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos16\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos16\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos16\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos16\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos16\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos16\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos16\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos16\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos16\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos16\Part5.jpg
# Imagen rotada guardada en: data_augmentation\kos16\Part5_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos16\Part5_res.jpg
# Imagen original guardada en: data_augmentation\kos16\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos16\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos16\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos16\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos17\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos17\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos17\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos17\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos17\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos17\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos17\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos17\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos17\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos17\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos17\Part5.jpg
# Imagen rotada guardada en: data_augmentation\kos17\Part5_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos17\Part5_res.jpg
# Imagen original guardada en: data_augmentation\kos17\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos17\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos17\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos17\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos18\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos18\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos18\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos18\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos18\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos18\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos18\Part3.jpg
# Imagen rotada guardada en: data_augmentation\kos18\Part3_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos18\Part3_res.jpg
# Imagen original guardada en: data_augmentation\kos18\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos18\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos18\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos18\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos18\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos18\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos18\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos18\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos19\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos19\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos19\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos19\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos19\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos19\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos19\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos19\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos19\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos19\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos19\Part5.jpg
# Imagen rotada guardada en: data_augmentation\kos19\Part5_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos19\Part5_res.jpg
# Imagen original guardada en: data_augmentation\kos19\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos19\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos19\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos19\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos20\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos20\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos20\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos20\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos20\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos20\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos20\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos20\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos20\Part4.jpg
# Imagen rotada guardada en: data_augmentation\kos20\Part4_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos20\Part4_res.jpg
# Imagen original guardada en: data_augmentation\kos20\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos20\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos20\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos20\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos20\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos20\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos21\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos21\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos21\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos21\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos21\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos21\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos21\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos21\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos21\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos21\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos21\Part5.jpg
# Imagen rotada guardada en: data_augmentation\kos21\Part5_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos21\Part5_res.jpg
# Imagen original guardada en: data_augmentation\kos21\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos21\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos22\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos22\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos22\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos22\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos22\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos22\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos22\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos22\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos22\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos22\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos22\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos22\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos22\Part6.jpg
# Imagen rotada guardada en: data_augmentation\kos22\Part6_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos22\Part6_res.jpg
# Imagen original guardada en: data_augmentation\kos22\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos22\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos23\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos23\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos23\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos23\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos23\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos23\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos23\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos23\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos23\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos23\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos23\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos23\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos23\Part6.jpg
# Imagen rotada guardada en: data_augmentation\kos23\Part6_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos23\Part6_res.jpg
# Imagen original guardada en: data_augmentation\kos23\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos23\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos24\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos24\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos24\Part1.jpg
# Imagen rotada guardada en: data_augmentation\kos24\Part1_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos24\Part1_res.jpg
# Imagen original guardada en: data_augmentation\kos24\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos24\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos24\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos24\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos24\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos24\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos24\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos24\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos24\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos24\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos24\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos24\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos25\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos25\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos25\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos25\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos25\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos25\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos25\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos25\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos25\Part4.jpg
# Imagen rotada guardada en: data_augmentation\kos25\Part4_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos25\Part4_res.jpg
# Imagen original guardada en: data_augmentation\kos25\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos25\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos25\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos25\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos25\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos25\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos26\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos26\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos26\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos26\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos26\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos26\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos26\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos26\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos26\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos26\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos26\Part5.jpg
# Imagen rotada guardada en: data_augmentation\kos26\Part5_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos26\Part5_res.jpg
# Imagen original guardada en: data_augmentation\kos26\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos26\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos26\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos26\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos27\Part0.jpg
# Imagen rotada guardada en: data_augmentation\kos27\Part0_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos27\Part0_res.jpg
# Imagen original guardada en: data_augmentation\kos27\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos27\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos27\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos27\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos27\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos27\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos27\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos27\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos27\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos27\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos27\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos27\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos27\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos27\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos28\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos28\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos28\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos28\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos28\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos28\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos28\Part3.jpg
# Imagen rotada guardada en: data_augmentation\kos28\Part3_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos28\Part3_res.jpg
# Imagen original guardada en: data_augmentation\kos28\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos28\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos28\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos28\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos28\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos28\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos28\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos28\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos29\Part0.jpg
# Imagen rotada guardada en: data_augmentation\kos29\Part0_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos29\Part0_res.jpg
# Imagen original guardada en: data_augmentation\kos29\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos29\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos29\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos29\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos29\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos29\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos29\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos29\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos29\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos29\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos29\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos29\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos29\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos29\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos30\Part0.jpg
# Imagen rotada guardada en: data_augmentation\kos30\Part0_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos30\Part0_res.jpg
# Imagen original guardada en: data_augmentation\kos30\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos30\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos30\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos30\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos30\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos30\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos30\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos30\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos30\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos30\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos30\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos30\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos30\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos30\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos31\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos31\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos31\Part1.jpg
# Imagen rotada guardada en: data_augmentation\kos31\Part1_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos31\Part1_res.jpg
# Imagen original guardada en: data_augmentation\kos31\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos31\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos31\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos31\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos31\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos31\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos31\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos31\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos31\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos31\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos31\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos31\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos32\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos32\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos32\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos32\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos32\Part2.jpg
# Imagen rotada guardada en: data_augmentation\kos32\Part2_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos32\Part2_res.jpg
# Imagen original guardada en: data_augmentation\kos32\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos32\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos32\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos32\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos32\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos32\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos32\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos32\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos32\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos32\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos33\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos33\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos33\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos33\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos33\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos33\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos33\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos33\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos33\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos33\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos33\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos33\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos33\Part6.jpg
# Imagen rotada guardada en: data_augmentation\kos33\Part6_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos33\Part6_res.jpg
# Imagen original guardada en: data_augmentation\kos33\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos33\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos34\Part0.jpg
# Imagen rotada guardada en: data_augmentation\kos34\Part0_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos34\Part0_res.jpg
# Imagen original guardada en: data_augmentation\kos34\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos34\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos34\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos34\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos34\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos34\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos34\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos34\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos34\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos34\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos34\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos34\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos34\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos34\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos35\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos35\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos35\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos35\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos35\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos35\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos35\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos35\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos35\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos35\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos35\Part5.jpg
# Imagen rotada guardada en: data_augmentation\kos35\Part5_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos35\Part5_res.jpg
# Imagen original guardada en: data_augmentation\kos35\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos35\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos35\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos35\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos36\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos36\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos36\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos36\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos36\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos36\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos36\Part3.jpg
# Imagen rotada guardada en: data_augmentation\kos36\Part3_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos36\Part3_res.jpg
# Imagen original guardada en: data_augmentation\kos36\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos36\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos36\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos36\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos36\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos36\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos36\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos36\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos37\Part0.jpg
# Imagen rotada guardada en: data_augmentation\kos37\Part0_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos37\Part0_res.jpg
# Imagen original guardada en: data_augmentation\kos37\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos37\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos37\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos37\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos37\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos37\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos37\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos37\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos37\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos37\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos37\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos37\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos37\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos37\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos38\Part0.jpg
# Imagen rotada guardada en: data_augmentation\kos38\Part0_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos38\Part0_res.jpg
# Imagen original guardada en: data_augmentation\kos38\Part1.jpg
# Imagen rotada guardada en: data_augmentation\kos38\Part1_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos38\Part1_res.jpg
# Imagen original guardada en: data_augmentation\kos38\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos38\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos38\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos38\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos38\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos38\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos38\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos38\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos38\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos38\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos38\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos38\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos39\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos39\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos39\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos39\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos39\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos39\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos39\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos39\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos39\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos39\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos39\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos39\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos39\Part6.jpg
# Imagen rotada guardada en: data_augmentation\kos39\Part6_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos39\Part6_res.jpg
# Imagen original guardada en: data_augmentation\kos39\Part7.jpg
# Imagen rotada guardada en: data_augmentation\kos39\Part7_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos39\Part7_res.jpg
# Imagen original guardada en: data_augmentation\kos40\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos40\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos40\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos40\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos40\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos40\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos40\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos40\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos40\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos40\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos40\Part5.jpg
# Imagen rotada guardada en: data_augmentation\kos40\Part5_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos40\Part5_res.jpg
# Imagen original guardada en: data_augmentation\kos40\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos40\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos40\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos40\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos41\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos41\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos41\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos41\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos41\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos41\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos41\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos41\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos41\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos41\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos41\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos41\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos41\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos41\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos41\Part7.jpg
# Imagen rotada guardada en: data_augmentation\kos41\Part7_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos41\Part7_res.jpg
# Imagen original guardada en: data_augmentation\kos42\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos42\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos42\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos42\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos42\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos42\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos42\Part3.jpg
# Imagen rotada guardada en: data_augmentation\kos42\Part3_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos42\Part3_res.jpg
# Imagen original guardada en: data_augmentation\kos42\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos42\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos42\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos42\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos42\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos42\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos42\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos42\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos43\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos43\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos43\Part1.jpg
# Imagen rotada guardada en: data_augmentation\kos43\Part1_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos43\Part1_res.jpg
# Imagen original guardada en: data_augmentation\kos43\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos43\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos43\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos43\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos43\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos43\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos43\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos43\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos43\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos43\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos43\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos43\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos44\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos44\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos44\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos44\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos44\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos44\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos44\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos44\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos44\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos44\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos44\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos44\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos44\Part6.jpg
# Imagen rotada guardada en: data_augmentation\kos44\Part6_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos44\Part6_res.jpg
# Imagen original guardada en: data_augmentation\kos44\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos44\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos45\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos45\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos45\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos45\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos45\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos45\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos45\Part3.jpg
# Imagen rotada guardada en: data_augmentation\kos45\Part3_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos45\Part3_res.jpg
# Imagen original guardada en: data_augmentation\kos45\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos45\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos45\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos45\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos45\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos45\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos45\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos45\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos46\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos46\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos46\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos46\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos46\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos46\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos46\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos46\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos46\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos46\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos46\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos46\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos46\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos46\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos46\Part7.jpg
# Imagen rotada guardada en: data_augmentation\kos46\Part7_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos46\Part7_res.jpg
# Imagen original guardada en: data_augmentation\kos47\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos47\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos47\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos47\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos47\Part2.jpg
# Imagen rotada guardada en: data_augmentation\kos47\Part2_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos47\Part2_res.jpg
# Imagen original guardada en: data_augmentation\kos47\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos47\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos47\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos47\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos47\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos47\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos47\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos47\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos47\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos47\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos48\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos48\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos48\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos48\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos48\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos48\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos48\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos48\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos48\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos48\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos48\Part5.jpg
# Imagen rotada guardada en: data_augmentation\kos48\Part5_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos48\Part5_res.jpg
# Imagen original guardada en: data_augmentation\kos48\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos48\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos48\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos48\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos49\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos49\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos49\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos49\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos49\Part2.jpg
# Imagen rotada guardada en: data_augmentation\kos49\Part2_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos49\Part2_res.jpg
# Imagen original guardada en: data_augmentation\kos49\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos49\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos49\Part4.jpg
# Archivo .bmp copiado en: data_augmentation\kos49\Part4_label.bmp
# Imagen original guardada en: data_augmentation\kos49\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos49\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos49\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos49\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos49\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos49\Part7_label.bmp
# Imagen original guardada en: data_augmentation\kos50\Part0.jpg
# Archivo .bmp copiado en: data_augmentation\kos50\Part0_label.bmp
# Imagen original guardada en: data_augmentation\kos50\Part1.jpg
# Archivo .bmp copiado en: data_augmentation\kos50\Part1_label.bmp
# Imagen original guardada en: data_augmentation\kos50\Part2.jpg
# Archivo .bmp copiado en: data_augmentation\kos50\Part2_label.bmp
# Imagen original guardada en: data_augmentation\kos50\Part3.jpg
# Archivo .bmp copiado en: data_augmentation\kos50\Part3_label.bmp
# Imagen original guardada en: data_augmentation\kos50\Part4.jpg
# Imagen rotada guardada en: data_augmentation\kos50\Part4_rot.jpg
# Imagen espejo guardada en: data_augmentation\kos50\Part4_res.jpg
# Imagen original guardada en: data_augmentation\kos50\Part5.jpg
# Archivo .bmp copiado en: data_augmentation\kos50\Part5_label.bmp
# Imagen original guardada en: data_augmentation\kos50\Part6.jpg
# Archivo .bmp copiado en: data_augmentation\kos50\Part6_label.bmp
# Imagen original guardada en: data_augmentation\kos50\Part7.jpg
# Archivo .bmp copiado en: data_augmentation\kos50\Part7_label.bmp

# %%
df=get_jpg_paths_with_defects('data_augmentation')
print(df)
# Out:
#            relative_path  defecto
# 0        kos01\Part0.jpg        0
# 1        kos01\Part1.jpg        0
# 2        kos01\Part2.jpg        0
# 3        kos01\Part3.jpg        0
# 4        kos01\Part4.jpg        0
# ..                   ...      ...
# 498  kos50\Part4_res.jpg        1
# 499  kos50\Part4_rot.jpg        1
# 500      kos50\Part5.jpg        0
# 501      kos50\Part6.jpg        0
# 502      kos50\Part7.jpg        0
#
# [503 rows x 2 columns]

# %%
# Guardamos el DataFrame en un archivo CSV
df.to_csv("defectos_info.csv", index=False)

# %%
df.value_counts('defecto')
# Out:
# defecto
# 0    347
# 1    156
# Name: count, dtype: int64

# %% [markdown]
# Con este data augmentation hemos generado más errorores a partir de imagen giradas 180º y espejo; vacilitando a la hora del entranimiento tener un conjunto de datos más equilibrado.
